# %% [markdown]
# # **Notebook para criar um ficheiro csv com a informação referente ao dataset de scans**
# <hr>
#
# As input data, it will be used FDG-PET/CT and radiotherapy planning CT imaging data from 298 head and neck cancer patients.
#
# The data comes from four different institutions:
#  - __* (HGJ)  Hôpital Général Juif, Montréal - Discovery ST, GE Healthcare *__
#              - for some patients the contours were drawn the same way as HMR
#              but the other were directly drawn on the CT scan of the FDG-PET/CT scan
#  - __* (CHUS) Centre Hospitalier Universitaire de Sherbooke, Sherbrooke - Guardian Body, Philips Medical Systems *__
#               - for some patients the contours were drawn the same way as HMR
#              but the other were directly drawn on the CT scan of the FDG-PET/CT scan
#  - __* (HMR)  Hôpital Maisonneuve-Rosemont, Montréal - Discovery STE, GE Healthcare  *__
#              - the radiotherapy contours were drawn on a different CT scan dedicated to treatment planning
#              and then propagated to the FDG-PET/CT scan reference frame
#              using deformable registration with the software MIM
#  - __* (CHUM) Centre Hospitalier de l’Université de Montréal, Montréal - Discovery ST, GE Healthcare  *__
#              - all patients received their FDG-PET/CT scan dedicated to the head and neck area
#              right before their planning CT scan, in the same position with the immobilisation device.
#              Contours defining the gross tumour volume (GTV) and lymph nodes were
#              drawn by an expert radiation oncologist on the planning CT scan
# <br><br>

# %%
import nibabel as nib
import numpy as np
import os
from glob import glob
import fnmatch
import pandas as pd
import pydicom
import csv
import types
import os.path

# %%
def create_csv_dataset(dataPath):
    scansPath = glob(dataPath+'*/*/*/*.dcm', recursive=True) #lista com o caminho de cada um dos dados na diretoria
    print("Total of %d DICOM images." %len(scansPath)) #retorna o numero de scans
    t=0
    scans=[]
    #scans_dose = [] 
    #mod = []
    for file in scansPath: 
        
        ds = pydicom.filereader.dcmread(file)
        modality = ds.Modality
        
            
        #path, filename = os.path.split(file) #print(path) #retorna somente o caminho #print(filename) #retorna somente o nome
        path=file[len(dataPath):] # para retirar o dataPath que veio como parametro
        lf=path.split("/") #para colocar as subdiretorias numa lista
        #['HN-HGJ-040', '08-27-1885-HN-04353', '3-2.5mm-20274', '000068.dcm']
        t+=1
        if t < 10:
            print(lf) #para imprimir os primeiros 10 registos
        id_sep=lf[0].split("-") #para poder ir buscar o nome do hospital
        
        lf.insert(1, id_sep[1]) 
        lf.append(modality)
        
                     
        
        if 'PixelData' in ds:
            rows = int(ds.Rows)
            cols = int(ds.Columns)
            size = len(ds.PixelData)
            
        else:
            rows = 0
            cols = 0
            size = 0

            
                    
        lf.append(rows)
        lf.append(cols)    
        #lf.append(depth)
        lf.append(size)
        #lf.append(numberOfFrames)
        scans.append(lf)
        
    #criar o dataframe
    df = pd.DataFrame(scans, columns = ['patient', 'instituition','path1', 'path2','dcm','Modality','Rows','Columns','Size- bytes']) 
    #df.insert(loc=5, column='Modality', value=mod)
    #df_final = df.loc[(df['Modality'] == 'RTPLAN') & (df['Modality'] == 'RTSTRUCT') & (df['Modality'] == 'REG')]
    #df_1= df.drop(df_final.index)
    #vai ser preferivel colocar toda a informação num dataframe e depois colocar as imagens num numpyarray
    
    #o dataframe deve ser colocado num ficheiro csv para poder ser editado a qualquer momento
    df.to_csv ('complete_Head-Neck_dataset.csv')
    #df_1.to_csv ('semi_Head-Neck_dataset.csv')
    #print("numero de scans na lista:", len(scans)) #retorna o numero de scans
    #print("numero de scans dose na lista:", len(scans_dose)) #retorna o numero de scans com a palavra dose
    return df
    #return df_1


# diretoria onde estao os exames com labels
dataPath = '../../data/tcia/Head-Neck-PET-CT/'
df = create_csv_dataset(dataPath)
df
#df_1

#todos são 123271
# Out:
# Total of 123271 DICOM images.
# ['HN-HGJ-040', '08-27-1885-HN-04353', '4-ARIA RadOnc Structure Sets-21343', '000000.dcm']
# ['HN-HGJ-040', '08-27-1885-HN-04353', '3-2.5mm-20274', '000068.dcm']
# ['HN-HGJ-040', '08-27-1885-HN-04353', '3-2.5mm-20274', '000099.dcm']
# ['HN-HGJ-040', '08-27-1885-HN-04353', '3-2.5mm-20274', '000126.dcm']
# ['HN-HGJ-040', '08-27-1885-HN-04353', '3-2.5mm-20274', '000041.dcm']
# ['HN-HGJ-040', '08-27-1885-HN-04353', '3-2.5mm-20274', '000127.dcm']
# ['HN-HGJ-040', '08-27-1885-HN-04353', '3-2.5mm-20274', '000110.dcm']
# ['HN-HGJ-040', '08-27-1885-HN-04353', '3-2.5mm-20274', '000124.dcm']
# ['HN-HGJ-040', '08-27-1885-HN-04353', '3-2.5mm-20274', '000141.dcm']
#             patient instituition                           path1  \
# 0        HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 1        HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 2        HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 3        HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 4        HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 5        HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 6        HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 7        HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 8        HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 9        HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 10       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 11       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 12       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 13       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 14       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 15       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 16       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 17       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 18       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 19       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 20       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 21       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 22       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 23       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 24       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 25       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 26       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 27       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 28       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 29       HN-HGJ-040          HGJ             08-27-1885-HN-04353
# ...             ...          ...                             ...
# 123241  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123242  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123243  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123244  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123245  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123246  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123247  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123248  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123249  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123250  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123251  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123252  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123253  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123254  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123255  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123256  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123257  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123258  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123259  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123260  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123261  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123262  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123263  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123264  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123265  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123266  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123267  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123268  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123269  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123270  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
#
#                                      path2         dcm  Modality  Rows  \
# 0       4-ARIA RadOnc Structure Sets-21343  000000.dcm  RTSTRUCT     0
# 1                            3-2.5mm-20274  000068.dcm        CT   512
# 2                            3-2.5mm-20274  000099.dcm        CT   512
# 3                            3-2.5mm-20274  000126.dcm        CT   512
# 4                            3-2.5mm-20274  000041.dcm        CT   512
# 5                            3-2.5mm-20274  000127.dcm        CT   512
# 6                            3-2.5mm-20274  000110.dcm        CT   512
# 7                            3-2.5mm-20274  000124.dcm        CT   512
# 8                            3-2.5mm-20274  000141.dcm        CT   512
# 9                            3-2.5mm-20274  000086.dcm        CT   512
# 10                           3-2.5mm-20274  000000.dcm        CT   512
# 11                           3-2.5mm-20274  000077.dcm        CT   512
# 12                           3-2.5mm-20274  000143.dcm        CT   512
# 13                           3-2.5mm-20274  000052.dcm        CT   512
# 14                           3-2.5mm-20274  000029.dcm        CT   512
# 15                           3-2.5mm-20274  000129.dcm        CT   512
# 16                           3-2.5mm-20274  000109.dcm        CT   512
# 17                           3-2.5mm-20274  000145.dcm        CT   512
# 18                           3-2.5mm-20274  000006.dcm        CT   512
# 19                           3-2.5mm-20274  000122.dcm        CT   512
# 20                           3-2.5mm-20274  000039.dcm        CT   512
# 21                           3-2.5mm-20274  000092.dcm        CT   512
# 22                           3-2.5mm-20274  000087.dcm        CT   512
# 23                           3-2.5mm-20274  000079.dcm        CT   512
# 24                           3-2.5mm-20274  000128.dcm        CT   512
# 25                           3-2.5mm-20274  000009.dcm        CT   512
# 26                           3-2.5mm-20274  000040.dcm        CT   512
# 27                           3-2.5mm-20274  000061.dcm        CT   512
# 28                           3-2.5mm-20274  000008.dcm        CT   512
# 29                           3-2.5mm-20274  000025.dcm        CT   512
# ...                                    ...         ...       ...   ...
# 123241                      3-Merged-07664  000095.dcm        CT   512
# 123242                      3-Merged-07664  000051.dcm        CT   512
# 123243                      3-Merged-07664  000084.dcm        CT   512
# 123244                      3-Merged-07664  000116.dcm        CT   512
# 123245                      3-Merged-07664  000002.dcm        CT   512
# 123246                      3-Merged-07664  000106.dcm        CT   512
# 123247                      3-Merged-07664  000054.dcm        CT   512
# 123248                      3-Merged-07664  000019.dcm        CT   512
# 123249                      3-Merged-07664  000038.dcm        CT   512
# 123250                      3-Merged-07664  000017.dcm        CT   512
# 123251                      3-Merged-07664  000010.dcm        CT   512
# 123252                      3-Merged-07664  000117.dcm        CT   512
# 123253                      3-Merged-07664  000027.dcm        CT   512
# 123254                      3-Merged-07664  000115.dcm        CT   512
# 123255                      3-Merged-07664  000090.dcm        CT   512
# 123256                      3-Merged-07664  000073.dcm        CT   512
# 123257                      3-Merged-07664  000011.dcm        CT   512
# 123258                      3-Merged-07664  000083.dcm        CT   512
# 123259                      3-Merged-07664  000055.dcm        CT   512
# 123260                      3-Merged-07664  000123.dcm        CT   512
# 123261                      3-Merged-07664  000119.dcm        CT   512
# 123262                      3-Merged-07664  000044.dcm        CT   512
# 123263                      3-Merged-07664  000112.dcm        CT   512
# 123264                      3-Merged-07664  000089.dcm        CT   512
# 123265                      3-Merged-07664  000105.dcm        CT   512
# 123266                      3-Merged-07664  000114.dcm        CT   512
# 123267                      3-Merged-07664  000094.dcm        CT   512
# 123268                      3-Merged-07664  000059.dcm        CT   512
# 123269                  Pinnacle ROI-25743  000000.dcm  RTSTRUCT     0
# 123270     1-RTstructCTsim-PETPET-CT-24615  000000.dcm  RTSTRUCT     0
#
#         Columns  Size- bytes
# 0             0            0
# 1           512       524288
# 2           512       524288
# 3           512       524288
# 4           512       524288
# 5           512       524288
# 6           512       524288
# 7           512       524288
# 8           512       524288
# 9           512       524288
# 10          512       524288
# 11          512       524288
# 12          512       524288
# 13          512       524288
# 14          512       524288
# 15          512       524288
# 16          512       524288
# 17          512       524288
# 18          512       524288
# 19          512       524288
# 20          512       524288
# 21          512       524288
# 22          512       524288
# 23          512       524288
# 24          512       524288
# 25          512       524288
# 26          512       524288
# 27          512       524288
# 28          512       524288
# 29          512       524288
# ...         ...          ...
# 123241      512       524288
# 123242      512       524288
# 123243      512       524288
# 123244      512       524288
# 123245      512       524288
# 123246      512       524288
# 123247      512       524288
# 123248      512       524288
# 123249      512       524288
# 123250      512       524288
# 123251      512       524288
# 123252      512       524288
# 123253      512       524288
# 123254      512       524288
# 123255      512       524288
# 123256      512       524288
# 123257      512       524288
# 123258      512       524288
# 123259      512       524288
# 123260      512       524288
# 123261      512       524288
# 123262      512       524288
# 123263      512       524288
# 123264      512       524288
# 123265      512       524288
# 123266      512       524288
# 123267      512       524288
# 123268      512       524288
# 123269        0            0
# 123270        0            0
#
# [123271 rows x 9 columns]

# %%
dataset = pd.read_csv('complete_Head-Neck_dataset.csv')

dataset['Modality'].value_counts()
# Out:
# CT          75569
# PT          45839
# RTSTRUCT      831
# RTDOSE        497
# RTPLAN        329
# REG           206
# Name: Modality, dtype: int64

# %%
array=['CT','PT','RTSTRUCT']

dataset.loc[dataset['Modality'].isin(array)]
# Out:
#         Unnamed: 0      patient instituition                           path1  \
# 0                0   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 1                1   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 2                2   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 3                3   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 4                4   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 5                5   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 6                6   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 7                7   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 8                8   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 9                9   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 10              10   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 11              11   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 12              12   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 13              13   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 14              14   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 15              15   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 16              16   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 17              17   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 18              18   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 19              19   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 20              20   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 21              21   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 22              22   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 23              23   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 24              24   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 25              25   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 26              26   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 27              27   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 28              28   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# 29              29   HN-HGJ-040          HGJ             08-27-1885-HN-04353
# ...            ...          ...          ...                             ...
# 123241      123241  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123242      123242  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123243      123243  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123244      123244  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123245      123245  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123246      123246  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123247      123247  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123248      123248  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123249      123249  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123250      123250  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123251      123251  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123252      123252  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123253      123253  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123254      123254  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123255      123255  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123256      123256  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123257      123257  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123258      123258  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123259      123259  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123260      123260  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123261      123261  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123262      123262  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123263      123263  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123264      123264  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123265      123265  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123266      123266  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123267      123267  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123268      123268  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123269      123269  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
# 123270      123270  HN-CHUS-003         CHUS  08-27-1885-BILAN INITIAL-49252
#
#                                      path2         dcm  Modality  Rows  \
# 0       4-ARIA RadOnc Structure Sets-21343  000000.dcm  RTSTRUCT     0
# 1                            3-2.5mm-20274  000068.dcm        CT   512
# 2                            3-2.5mm-20274  000099.dcm        CT   512
# 3                            3-2.5mm-20274  000126.dcm        CT   512
# 4                            3-2.5mm-20274  000041.dcm        CT   512
# 5                            3-2.5mm-20274  000127.dcm        CT   512
# 6                            3-2.5mm-20274  000110.dcm        CT   512
# 7                            3-2.5mm-20274  000124.dcm        CT   512
# 8                            3-2.5mm-20274  000141.dcm        CT   512
# 9                            3-2.5mm-20274  000086.dcm        CT   512
# 10                           3-2.5mm-20274  000000.dcm        CT   512
# 11                           3-2.5mm-20274  000077.dcm        CT   512
# 12                           3-2.5mm-20274  000143.dcm        CT   512
# 13                           3-2.5mm-20274  000052.dcm        CT   512
# 14                           3-2.5mm-20274  000029.dcm        CT   512
# 15                           3-2.5mm-20274  000129.dcm        CT   512
# 16                           3-2.5mm-20274  000109.dcm        CT   512
# 17                           3-2.5mm-20274  000145.dcm        CT   512
# 18                           3-2.5mm-20274  000006.dcm        CT   512
# 19                           3-2.5mm-20274  000122.dcm        CT   512
# 20                           3-2.5mm-20274  000039.dcm        CT   512
# 21                           3-2.5mm-20274  000092.dcm        CT   512
# 22                           3-2.5mm-20274  000087.dcm        CT   512
# 23                           3-2.5mm-20274  000079.dcm        CT   512
# 24                           3-2.5mm-20274  000128.dcm        CT   512
# 25                           3-2.5mm-20274  000009.dcm        CT   512
# 26                           3-2.5mm-20274  000040.dcm        CT   512
# 27                           3-2.5mm-20274  000061.dcm        CT   512
# 28                           3-2.5mm-20274  000008.dcm        CT   512
# 29                           3-2.5mm-20274  000025.dcm        CT   512
# ...                                    ...         ...       ...   ...
# 123241                      3-Merged-07664  000095.dcm        CT   512
# 123242                      3-Merged-07664  000051.dcm        CT   512
# 123243                      3-Merged-07664  000084.dcm        CT   512
# 123244                      3-Merged-07664  000116.dcm        CT   512
# 123245                      3-Merged-07664  000002.dcm        CT   512
# 123246                      3-Merged-07664  000106.dcm        CT   512
# 123247                      3-Merged-07664  000054.dcm        CT   512
# 123248                      3-Merged-07664  000019.dcm        CT   512
# 123249                      3-Merged-07664  000038.dcm        CT   512
# 123250                      3-Merged-07664  000017.dcm        CT   512
# 123251                      3-Merged-07664  000010.dcm        CT   512
# 123252                      3-Merged-07664  000117.dcm        CT   512
# 123253                      3-Merged-07664  000027.dcm        CT   512
# 123254                      3-Merged-07664  000115.dcm        CT   512
# 123255                      3-Merged-07664  000090.dcm        CT   512
# 123256                      3-Merged-07664  000073.dcm        CT   512
# 123257                      3-Merged-07664  000011.dcm        CT   512
# 123258                      3-Merged-07664  000083.dcm        CT   512
# 123259                      3-Merged-07664  000055.dcm        CT   512
# 123260                      3-Merged-07664  000123.dcm        CT   512
# 123261                      3-Merged-07664  000119.dcm        CT   512
# 123262                      3-Merged-07664  000044.dcm        CT   512
# 123263                      3-Merged-07664  000112.dcm        CT   512
# 123264                      3-Merged-07664  000089.dcm        CT   512
# 123265                      3-Merged-07664  000105.dcm        CT   512
# 123266                      3-Merged-07664  000114.dcm        CT   512
# 123267                      3-Merged-07664  000094.dcm        CT   512
# 123268                      3-Merged-07664  000059.dcm        CT   512
# 123269                  Pinnacle ROI-25743  000000.dcm  RTSTRUCT     0
# 123270     1-RTstructCTsim-PETPET-CT-24615  000000.dcm  RTSTRUCT     0
#
#         Columns  Size- bytes
# 0             0            0
# 1           512       524288
# 2           512       524288
# 3           512       524288
# 4           512       524288
# 5           512       524288
# 6           512       524288
# 7           512       524288
# 8           512       524288
# 9           512       524288
# 10          512       524288
# 11          512       524288
# 12          512       524288
# 13          512       524288
# 14          512       524288
# 15          512       524288
# 16          512       524288
# 17          512       524288
# 18          512       524288
# 19          512       524288
# 20          512       524288
# 21          512       524288
# 22          512       524288
# 23          512       524288
# 24          512       524288
# 25          512       524288
# 26          512       524288
# 27          512       524288
# 28          512       524288
# 29          512       524288
# ...         ...          ...
# 123241      512       524288
# 123242      512       524288
# 123243      512       524288
# 123244      512       524288
# 123245      512       524288
# 123246      512       524288
# 123247      512       524288
# 123248      512       524288
# 123249      512       524288
# 123250      512       524288
# 123251      512       524288
# 123252      512       524288
# 123253      512       524288
# 123254      512       524288
# 123255      512       524288
# 123256      512       524288
# 123257      512       524288
# 123258      512       524288
# 123259      512       524288
# 123260      512       524288
# 123261      512       524288
# 123262      512       524288
# 123263      512       524288
# 123264      512       524288
# 123265      512       524288
# 123266      512       524288
# 123267      512       524288
# 123268      512       524288
# 123269        0            0
# 123270        0            0
#
# [122239 rows x 10 columns]

# %%
#todas as pastas que contem o exame CT
#falta a condicao: e que tambem tem PET
#quero todos os valores da coluna path1 em que tenha OBRIGATORIAMENTE modalidade PET e CT


#dataset.loc[dataset['path1'].where(dataset.query(path1= True and (Modality=='CT' or Modality=='PT'))]

# %%
pd.Series(dataset.Modality.values,index=dataset.path1)
# Out:
# path1
# 08-27-1885-HN-04353               RTSTRUCT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
# 08-27-1885-HN-04353                     CT
#                                     ...
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252          CT
# 08-27-1885-BILAN INITIAL-49252    RTSTRUCT
# 08-27-1885-BILAN INITIAL-49252    RTSTRUCT
# Length: 123271, dtype: object

# %%
#Criar um dicionario dos paths1- elimina os repetidos
#loc para cada elemento- da as linhas
#Selecionar os que tem as 2 modalidades

# to get key value using pandas
#path_dict = dict(zip(dataset.path1, dataset.Modality))
#print(path_dict)


# converting to dict 
#data_dict = dataset.to_dict() 
  
# printing datatype of first keys value in dict 
#print(type(data_dict['path1'])) 

# display 
#data_dict

#pd.Series(dataset.Modality.values,index=dataset.path1).to_dict()

#len(pd.Series(dataset.Modality.values,index=dataset.path1).to_dict())

#dataset.set_index('path1').T.to_dict('list')


#dataset.groupby('path1').filter(items = [dataset['Modality']]).drop_duplicates(subset=['Modality'], keep="first")


dataset.drop_duplicates(subset=['path1', 'Modality'], keep="first").drop(columns=['Unnamed: 0','path2','dcm','Rows','Columns','Size- bytes']).to_csv('paths.csv')

# %%
a = pd.read_csv('paths.csv')

# %%
a.drop(columns=['Unnamed: 0'])
# Out:
#           patient instituition  \
# 0      HN-HGJ-040          HGJ
# 1      HN-HGJ-040          HGJ
# 2      HN-HGJ-040          HGJ
# 3      HN-HGJ-040          HGJ
# 4      HN-HGJ-040          HGJ
# 5      HN-HGJ-040          HGJ
# 6      HN-HGJ-040          HGJ
# 7      HN-HGJ-040          HGJ
# 8      HN-HGJ-040          HGJ
# 9     HN-CHUS-091         CHUS
# 10    HN-CHUS-091         CHUS
# 11    HN-CHUS-091         CHUS
# 12    HN-CHUS-091         CHUS
# 13    HN-CHUS-091         CHUS
# 14    HN-CHUM-026         CHUM
# 15    HN-CHUM-026         CHUM
# 16    HN-CHUM-026         CHUM
# 17    HN-CHUM-026         CHUM
# 18    HN-CHUM-026         CHUM
# 19    HN-CHUM-026         CHUM
# 20    HN-CHUM-026         CHUM
# 21    HN-CHUM-026         CHUM
# 22    HN-CHUM-026         CHUM
# 23    HN-CHUS-043         CHUS
# 24    HN-CHUS-043         CHUS
# 25    HN-CHUS-043         CHUS
# 26    HN-CHUS-043         CHUS
# 27    HN-CHUS-043         CHUS
# 28     HN-HMR-040          HMR
# 29     HN-HMR-040          HMR
# ...           ...          ...
# 2101   HN-HGJ-092          HGJ
# 2102   HN-HGJ-092          HGJ
# 2103   HN-HGJ-092          HGJ
# 2104  HN-CHUS-031         CHUS
# 2105  HN-CHUS-031         CHUS
# 2106  HN-CHUS-031         CHUS
# 2107  HN-CHUS-031         CHUS
# 2108  HN-CHUS-031         CHUS
# 2109  HN-CHUS-052         CHUS
# 2110  HN-CHUS-052         CHUS
# 2111  HN-CHUS-052         CHUS
# 2112  HN-CHUS-052         CHUS
# 2113  HN-CHUS-052         CHUS
# 2114  HN-CHUM-034         CHUM
# 2115  HN-CHUM-034         CHUM
# 2116  HN-CHUM-034         CHUM
# 2117  HN-CHUM-034         CHUM
# 2118  HN-CHUM-034         CHUM
# 2119  HN-CHUM-034         CHUM
# 2120  HN-CHUM-034         CHUM
# 2121  HN-CHUM-034         CHUM
# 2122  HN-CHUM-034         CHUM
# 2123  HN-CHUS-061         CHUS
# 2124  HN-CHUS-061         CHUS
# 2125  HN-CHUS-061         CHUS
# 2126  HN-CHUS-061         CHUS
# 2127  HN-CHUS-061         CHUS
# 2128  HN-CHUS-003         CHUS
# 2129  HN-CHUS-003         CHUS
# 2130  HN-CHUS-003         CHUS
#
#                                                 path1  Modality
# 0                                 08-27-1885-HN-04353  RTSTRUCT
# 1                                 08-27-1885-HN-04353        CT
# 2                                 08-27-1885-HN-04353    RTPLAN
# 3                                 08-27-1885-HN-04353    RTDOSE
# 4                                 08-27-1885-HN-04353       REG
# 5                  08-27-1885-PET HEAD AND NECK-48050  RTSTRUCT
# 6                  08-27-1885-PET HEAD AND NECK-48050        CT
# 7                  08-27-1885-PET HEAD AND NECK-48050        PT
# 8                  08-27-1885-PET HEAD AND NECK-48050    RTDOSE
# 9           08-27-1885-CA ORL FDG TEP POS TRAIT-29027  RTSTRUCT
# 10          08-27-1885-CA ORL FDG TEP POS TRAIT-29027        CT
# 11          08-27-1885-CA ORL FDG TEP POS TRAIT-29027        PT
# 12          08-27-1885-CA ORL FDG TEP POS TRAIT-29027    RTDOSE
# 13          08-27-1885-CA ORL FDG TEP POS TRAIT-29027    RTPLAN
# 14       08-27-1885-TomoTherapy Patient Disease-41326       REG
# 15       08-27-1885-TomoTherapy Patient Disease-41326  RTSTRUCT
# 16       08-27-1885-TomoTherapy Patient Disease-41326    RTDOSE
# 17       08-27-1885-TomoTherapy Patient Disease-41326    RTPLAN
# 18       08-27-1885-TomoTherapy Patient Disease-41326        CT
# 19    08-27-1885-PANC. avec C.A. SPHRE ORL  -TP-85645        PT
# 20    08-27-1885-PANC. avec C.A. SPHRE ORL  -TP-85645        CT
# 21    08-27-1885-PANC. avec C.A. SPHRE ORL  -TP-85645    RTDOSE
# 22    08-27-1885-PANC. avec C.A. SPHRE ORL  -TP-85645  RTSTRUCT
# 23                 08-27-1885-CARCINOME FDG TEP-75326    RTDOSE
# 24                 08-27-1885-CARCINOME FDG TEP-75326  RTSTRUCT
# 25                 08-27-1885-CARCINOME FDG TEP-75326        PT
# 26                 08-27-1885-CARCINOME FDG TEP-75326        CT
# 27                 08-27-1885-CARCINOME FDG TEP-75326    RTPLAN
# 28              08-27-1885-TEP PANC. SPHERE ORL-20668        PT
# 29              08-27-1885-TEP PANC. SPHERE ORL-20668  RTSTRUCT
# ...                                               ...       ...
# 2101               08-27-1885-PET HEAD AND NECK-01768        CT
# 2102               08-27-1885-PET HEAD AND NECK-01768        PT
# 2103               08-27-1885-PET HEAD AND NECK-01768  RTSTRUCT
# 2104          08-27-1885-TEP cancerologique TEP-55339  RTSTRUCT
# 2105          08-27-1885-TEP cancerologique TEP-55339        CT
# 2106          08-27-1885-TEP cancerologique TEP-55339    RTDOSE
# 2107          08-27-1885-TEP cancerologique TEP-55339    RTPLAN
# 2108          08-27-1885-TEP cancerologique TEP-55339        PT
# 2109           08-27-1885-CA ORL FDG TEP POS TX-94629    RTPLAN
# 2110           08-27-1885-CA ORL FDG TEP POS TX-94629    RTDOSE
# 2111           08-27-1885-CA ORL FDG TEP POS TX-94629  RTSTRUCT
# 2112           08-27-1885-CA ORL FDG TEP POS TX-94629        CT
# 2113           08-27-1885-CA ORL FDG TEP POS TX-94629        PT
# 2114       08-27-1885-CT Planification - ORL TC-69506        PT
# 2115       08-27-1885-CT Planification - ORL TC-69506  RTSTRUCT
# 2116       08-27-1885-CT Planification - ORL TC-69506    RTDOSE
# 2117       08-27-1885-CT Planification - ORL TC-69506        CT
# 2118     08-27-1885-TomoTherapy Patient Disease-83113    RTPLAN
# 2119     08-27-1885-TomoTherapy Patient Disease-83113    RTDOSE
# 2120     08-27-1885-TomoTherapy Patient Disease-83113       REG
# 2121     08-27-1885-TomoTherapy Patient Disease-83113  RTSTRUCT
# 2122     08-27-1885-TomoTherapy Patient Disease-83113        CT
# 2123          08-27-1885-TEP cancerologique TEP-44835    RTPLAN
# 2124          08-27-1885-TEP cancerologique TEP-44835    RTDOSE
# 2125          08-27-1885-TEP cancerologique TEP-44835  RTSTRUCT
# 2126          08-27-1885-TEP cancerologique TEP-44835        CT
# 2127          08-27-1885-TEP cancerologique TEP-44835        PT
# 2128                   08-27-1885-BILAN INITIAL-49252        PT
# 2129                   08-27-1885-BILAN INITIAL-49252        CT
# 2130                   08-27-1885-BILAN INITIAL-49252  RTSTRUCT
#
# [2131 rows x 4 columns]

# %%
d = {}
for i in a['path1'].unique():
    d[i] = {a['Modality'][j] for j in a[a['path1']==i].index}

# %%
print (d)
# Out:
# {'08-27-1885-HN-04353': {'REG', 'RTDOSE', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-PET HEAD AND NECK-48050': {'RTSTRUCT', 'RTDOSE', 'PT', 'CT'}, '08-27-1885-CA ORL FDG TEP POS TRAIT-29027': {'RTDOSE', 'PT', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-TomoTherapy Patient Disease-41326': {'REG', 'RTDOSE', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-PANC. avec C.A. SPHRE ORL  -TP-85645': {'CT', 'RTDOSE', 'PT', 'RTSTRUCT'}, '08-27-1885-CARCINOME FDG TEP-75326': {'RTDOSE', 'PT', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-TEP PANC. SPHERE ORL-20668': {'RTSTRUCT', 'RTDOSE', 'PT', 'CT'}, '08-27-1885-COU-53414': {'REG', 'RTDOSE', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-PET HEAD NECK-34933': {'RTSTRUCT', 'PT', 'CT'}, '08-27-1885-HN CORVUS  CONTRAST-79004': {'RTSTRUCT', 'REG', 'CT'}, '08-27-1885-TEP AVEC SYNCHRONISTIO-30759': {'RTSTRUCT', 'RTDOSE', 'PT', 'CT'}, '08-27-1885-LARYNXCOU-39491': {'REG', 'RTDOSE', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-CA ORL FDG TEP-89483': {'RTDOSE', 'PT', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-PET HEAD AND NECK-49784': {'CT', 'RTDOSE', 'PT', 'RTSTRUCT'}, '08-27-1885-HN-06421': {'REG', 'RTDOSE', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-TETE-COU-36224': {'RTSTRUCT', 'RTDOSE', 'PT', 'CT'}, '08-27-1885-BASE DE LAGUECOU ANT-38867': {'REG', 'RTDOSE', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-TEP cancerologique TEP-09978': {'RTDOSE', 'PT', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-PET HEAD AND NECK-94585': {'CT', 'RTDOSE', 'PT', 'RTSTRUCT'}, '08-27-1885-HN-32796': {'REG', 'RTDOSE', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-TomoTherapy Patient Disease-27750': {'REG', 'RTDOSE', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-AMYGDALE TEP C-C-88657': {'CT', 'RTDOSE', 'PT', 'RTSTRUCT'}, '08-27-1885-60171': {'RTSTRUCT', 'REG', 'CT'}, '08-27-1885-PET HEAD NECK-03571': {'RTSTRUCT', 'PT', 'CT'}, '08-27-1885-TEP-TETE-COU-00079': {'REG', 'RTDOSE', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-ACQUISITIONS SUPPLMENTAIRES MAX. 1 CODEUSAGER-06106': {'CT', 'RTDOSE', 'PT', 'RTSTRUCT'}, '08-27-1885-CT pour planification -ONCO-81640': {'RTSTRUCT', 'RTDOSE', 'PT', 'CT'}, '08-27-1885-TomoTherapy Patient Disease-84736': {'REG', 'RTDOSE', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-CT Planification - ORL TC-13153': {'REG', 'RTDOSE', 'PT', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-CA ORL POS.TX-35346': {'CT', 'PT', 'RTSTRUCT'}, '08-27-1885-HN-37131': {'REG', 'RTDOSE', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-PET HEAD AND NECK-55486': {'RTSTRUCT', 'RTDOSE', 'PT', 'CT'}, '08-27-1885-CA AMYGDALE FDG TEP EN POS DE TX-92426': {'RTDOSE', 'PT', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-HN-42106': {'REG', 'RTDOSE', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-PET HEAD AND NECK-31045': {'CT', 'RTDOSE', 'PT', 'RTSTRUCT'}, '08-27-1885-HN-91459': {'REG', 'RTDOSE', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-PET HEAD AND NECK-30394': {'RTSTRUCT', 'RTDOSE', 'PT', 'CT'}, '08-27-1885-CA LARYNX-42453': {'RTSTRUCT', 'PT', 'CT'}, '08-27-1885-91407': {'CT', 'REG', 'RTSTRUCT'}, '08-27-1885-PET CT WB-32684': {'RTSTRUCT', 'PT', 'CT'}, '08-27-1885-PET HEAD AND NECK-00694': {'RTSTRUCT', 'RTDOSE', 'PT', 'CT'}, '08-27-1885-TONSILBILATERAL NECK-28144': {'REG', 'RTDOSE', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-TEP cancerologique TEP-80066': {'RTDOSE', 'PT', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-54323': {'RTSTRUCT', 'REG', 'CT'}, '08-27-1885-WB 2D-23183': {'CT', 'PT', 'RTSTRUCT'}, '08-27-1885-recherche de metastase fdg t-85380': {'RTDOSE', 'PT', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-CA ORL-59417': {'RTSTRUCT', 'PT', 'CT'}, '08-27-1885-TomoTherapy Patient Disease-91199': {'REG', 'RTDOSE', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-CT Planification - ORL TC-58685': {'RTSTRUCT', 'RTDOSE', 'PT', 'CT'}, '08-27-1885-CA ORL FDG TEP POS DE TX-99283': {'RTDOSE', 'PT', 'CT', 'RTPLAN', 'RTSTRUCT'}, '08-27-1885-PET HEAD NECK-90625': {'CT', 'PT', 'RTSTRUCT'}, '08-27-1885-28344': {'CT', 'REG', 'RTSTRUCT'}, '08-27-1885-PET HEAD AND NECK-54573': {'CT', 'RTDOSE', 'PT', 'RTSTRUCT'}, '08-27-1885-HEADNECK-037 ...

# %%
pd.DataFrame(list(d.items()), columns=['path1', 'Modalities'])
# Out:
#                                                  path1  \
# 0                                  08-27-1885-HN-04353
# 1                   08-27-1885-PET HEAD AND NECK-48050
# 2            08-27-1885-CA ORL FDG TEP POS TRAIT-29027
# 3         08-27-1885-TomoTherapy Patient Disease-41326
# 4      08-27-1885-PANC. avec C.A. SPHRE ORL  -TP-85645
# 5                   08-27-1885-CARCINOME FDG TEP-75326
# 6                08-27-1885-TEP PANC. SPHERE ORL-20668
# 7                                 08-27-1885-COU-53414
# 8                       08-27-1885-PET HEAD NECK-34933
# 9                 08-27-1885-HN CORVUS  CONTRAST-79004
# 10             08-27-1885-TEP AVEC SYNCHRONISTIO-30759
# 11                          08-27-1885-LARYNXCOU-39491
# 12                     08-27-1885-CA ORL FDG TEP-89483
# 13                  08-27-1885-PET HEAD AND NECK-49784
# 14                                 08-27-1885-HN-06421
# 15                           08-27-1885-TETE-COU-36224
# 16               08-27-1885-BASE DE LAGUECOU ANT-38867
# 17             08-27-1885-TEP cancerologique TEP-09978
# 18                  08-27-1885-PET HEAD AND NECK-94585
# 19                                 08-27-1885-HN-32796
# 20        08-27-1885-TomoTherapy Patient Disease-27750
# 21                   08-27-1885-AMYGDALE TEP C-C-88657
# 22                                    08-27-1885-60171
# 23                      08-27-1885-PET HEAD NECK-03571
# 24                       08-27-1885-TEP-TETE-COU-00079
# 25   08-27-1885-ACQUISITIONS SUPPLMENTAIRES MAX. 1 ...
# 26        08-27-1885-CT pour planification -ONCO-81640
# 27        08-27-1885-TomoTherapy Patient Disease-84736
# 28          08-27-1885-CT Planification - ORL TC-13153
# 29                      08-27-1885-CA ORL POS.TX-35346
# ..                                                 ...
# 474    08-27-1885-COPIE DE FILMS DE EXT TEP  -AU-57287
# 475       08-27-1885-TomoTherapy Patient Disease-71960
# 476                 08-27-1885-CARCINOME FDG TEP-78720
# 477                     08-27-1885-PET HEAD NECK-27589
# 478                  08-27-1885-HN WITH CONTRAST-30071
# 479                                   08-27-1885-65626
# 480                                   08-27-1885-76153
# 481                     08-27-1885-PET HEAD NECK-46758
# 482     08-27-1885-PANC. avec C.A.  PRIMAIRE -TP-17839
# 483       08-27-1885-TomoTherapy Patient Disease-22103
# 484             08-27-1885-ACQUISITIONS SUPPLMEN-01196
# 485             08-27-1885-ACQUISITIONS SUPPLMEN-81475
# 486                     08-27-1885-PET HEAD NECK-60917
# 487                                   08-27-1885-23319
# 488            08-27-1885-TEP cancerologique TEP-33500
# 489                    08-27-1885-CA ORL FDG TEP-33081
# 490      08-27-1885-CA AMYGDALE FDG TEP POSITION-32049
# 491                08-27-1885-PANC. TEP SHRE ORL-87919
# 492                         08-27-1885-LARYNXCOU-64222
# 493                         08-27-1885-PET OTHER-65278
# 494              08-27-1885-SUPRAGLOTTI AND NECK-87861
# 495            08-27-1885-TEP cancerologique TEP-77575
# 496                        08-27-1885-HEAD  NECK-64179
# 497                 08-27-1885-PET HEAD AND NECK-01768
# 498            08-27-1885-TEP cancerologique TEP-55339
# 499             08-27-1885-CA ORL FDG TEP POS TX-94629
# 500         08-27-1885-CT Planification - ORL TC-69506
# 501       08-27-1885-TomoTherapy Patient Disease-83113
# 502            08-27-1885-TEP cancerologique TEP-44835
# 503                     08-27-1885-BILAN INITIAL-49252
#
#                                   Modalities
# 0        {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 1                 {RTSTRUCT, RTDOSE, PT, CT}
# 2         {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 3        {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 4                 {CT, RTDOSE, PT, RTSTRUCT}
# 5         {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 6                 {RTSTRUCT, RTDOSE, PT, CT}
# 7        {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 8                         {RTSTRUCT, PT, CT}
# 9                        {RTSTRUCT, REG, CT}
# 10                {RTSTRUCT, RTDOSE, PT, CT}
# 11       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 12        {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 13                {CT, RTDOSE, PT, RTSTRUCT}
# 14       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 15                {RTSTRUCT, RTDOSE, PT, CT}
# 16       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 17        {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 18                {CT, RTDOSE, PT, RTSTRUCT}
# 19       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 20       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 21                {CT, RTDOSE, PT, RTSTRUCT}
# 22                       {RTSTRUCT, REG, CT}
# 23                        {RTSTRUCT, PT, CT}
# 24       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 25                {CT, RTDOSE, PT, RTSTRUCT}
# 26                {RTSTRUCT, RTDOSE, PT, CT}
# 27       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 28   {REG, RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 29                        {CT, PT, RTSTRUCT}
# ..                                       ...
# 474               {CT, RTDOSE, PT, RTSTRUCT}
# 475      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 476       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 477                       {RTSTRUCT, PT, CT}
# 478                      {RTSTRUCT, REG, CT}
# 479                               {RTSTRUCT}
# 480                                {CT, REG}
# 481                       {CT, PT, RTSTRUCT}
# 482               {RTSTRUCT, RTDOSE, PT, CT}
# 483      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 484               {CT, RTDOSE, PT, RTSTRUCT}
# 485      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 486                       {RTSTRUCT, PT, CT}
# 487                      {CT, REG, RTSTRUCT}
# 488       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 489       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 490       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 491               {RTSTRUCT, RTDOSE, PT, CT}
# 492      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 493               {RTSTRUCT, RTDOSE, PT, CT}
# 494      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 495       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 496      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 497               {CT, RTDOSE, PT, RTSTRUCT}
# 498       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 499       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 500               {RTSTRUCT, RTDOSE, PT, CT}
# 501      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 502       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 503                       {CT, PT, RTSTRUCT}
#
# [504 rows x 2 columns]

# %%
#Criar novo csv so com os paths, ou seja, sem os ficheiros dicom todos
def create_novo_csv(dataPath):
    scansPath = glob(dataPath+'*/*', recursive=True) #lista com o caminho de cada um dos dados na diretoria
    scans=[]
    

    for file in scansPath:
            
        #path, filename = os.path.split(file) #print(path) #retorna somente o caminho #print(filename) #retorna somente o nome
        path=file[len(dataPath):] # para retirar o dataPath que veio como parametro
        lf=path.split("/") #para colocar as subdiretorias numa lista
        #['HN-HGJ-040', '08-27-1885-HN-04353', '3-2.5mm-20274', '000068.dcm']

        id_sep=lf[0].split("-") #para poder ir buscar o nome do hospital
        
        lf.insert(1, id_sep[1]) 
                 
        scans.append(lf)
        
    #criar o dataframe
    df1 = pd.DataFrame(scans, columns = ['patient', 'instituition','path1']) 
    #vai ser preferivel colocar toda a informação num dataframe e depois colocar as imagens num numpyarray
    
    #o dataframe deve ser colocado num ficheiro csv para poder ser editado a qualquer momento
    df1.to_csv ('dataset_paths.csv')
  
    return df1



# diretoria onde estao os exames com labels
dataPath = '../../data/tcia/Head-Neck-PET-CT/'
df1 = create_novo_csv(dataPath)
df1
# Out:
#          patient instituition  \
# 0     HN-HGJ-040          HGJ
# 1     HN-HGJ-040          HGJ
# 2    HN-CHUS-091         CHUS
# 3    HN-CHUM-026         CHUM
# 4    HN-CHUM-026         CHUM
# 5    HN-CHUS-043         CHUS
# 6     HN-HMR-040          HMR
# 7     HN-HMR-040          HMR
# 8     HN-HGJ-056          HGJ
# 9     HN-HGJ-056          HGJ
# 10    HN-HMR-033          HMR
# 11    HN-HMR-033          HMR
# 12   HN-CHUS-058         CHUS
# 13    HN-HGJ-013          HGJ
# 14    HN-HGJ-013          HGJ
# 15    HN-HMR-011          HMR
# 16    HN-HMR-011          HMR
# 17   HN-CHUS-074         CHUS
# 18    HN-HGJ-084          HGJ
# 19    HN-HGJ-084          HGJ
# 20   HN-CHUM-050         CHUM
# 21   HN-CHUM-050         CHUM
# 22    HN-HGJ-054          HGJ
# 23    HN-HGJ-054          HGJ
# 24    HN-HMR-029          HMR
# 25    HN-HMR-029          HMR
# 26   HN-CHUM-008         CHUM
# 27   HN-CHUM-008         CHUM
# 28   HN-CHUM-059         CHUM
# 29   HN-CHUS-010         CHUS
# ..           ...          ...
# 474  HN-CHUM-065         CHUM
# 475  HN-CHUM-065         CHUM
# 476  HN-CHUS-034         CHUS
# 477   HN-HGJ-003          HGJ
# 478   HN-HGJ-003          HGJ
# 479   HN-HGJ-017          HGJ
# 480   HN-HGJ-017          HGJ
# 481   HN-HGJ-017          HGJ
# 482  HN-CHUM-005         CHUM
# 483  HN-CHUM-005         CHUM
# 484   HN-HMR-007          HMR
# 485   HN-HMR-007          HMR
# 486   HN-HGJ-011          HGJ
# 487   HN-HGJ-011          HGJ
# 488  HN-CHUS-063         CHUS
# 489  HN-CHUS-077         CHUS
# 490  HN-CHUS-066         CHUS
# 491   HN-HMR-036          HMR
# 492   HN-HMR-036          HMR
# 493   HN-HGJ-042          HGJ
# 494   HN-HGJ-042          HGJ
# 495  HN-CHUS-068         CHUS
# 496   HN-HGJ-092          HGJ
# 497   HN-HGJ-092          HGJ
# 498  HN-CHUS-031         CHUS
# 499  HN-CHUS-052         CHUS
# 500  HN-CHUM-034         CHUM
# 501  HN-CHUM-034         CHUM
# 502  HN-CHUS-061         CHUS
# 503  HN-CHUS-003         CHUS
#
#                                                  path1
# 0                                  08-27-1885-HN-04353
# 1                   08-27-1885-PET HEAD AND NECK-48050
# 2            08-27-1885-CA ORL FDG TEP POS TRAIT-29027
# %%
t = pd.read_csv('dataset_paths.csv')

# %%
df2 = pd.DataFrame(list(d.items()), columns=['path1', 'Modalities'])

# %%
pd.concat([t, df2], axis=1)
# Out:
#      Unnamed: 0      patient instituition  \
# 0             0   HN-HGJ-040          HGJ
# 1             1   HN-HGJ-040          HGJ
# 2             2  HN-CHUS-091         CHUS
# 3             3  HN-CHUM-026         CHUM
# 4             4  HN-CHUM-026         CHUM
# 5             5  HN-CHUS-043         CHUS
# 6             6   HN-HMR-040          HMR
# 7             7   HN-HMR-040          HMR
# 8             8   HN-HGJ-056          HGJ
# 9             9   HN-HGJ-056          HGJ
# 10           10   HN-HMR-033          HMR
# 11           11   HN-HMR-033          HMR
# 12           12  HN-CHUS-058         CHUS
# 13           13   HN-HGJ-013          HGJ
# 14           14   HN-HGJ-013          HGJ
# 15           15   HN-HMR-011          HMR
# 16           16   HN-HMR-011          HMR
# 17           17  HN-CHUS-074         CHUS
# 18           18   HN-HGJ-084          HGJ
# 19           19   HN-HGJ-084          HGJ
# 20           20  HN-CHUM-050         CHUM
# 21           21  HN-CHUM-050         CHUM
# 22           22   HN-HGJ-054          HGJ
# 23           23   HN-HGJ-054          HGJ
# 24           24   HN-HMR-029          HMR
# 25           25   HN-HMR-029          HMR
# 26           26  HN-CHUM-008         CHUM
# 27           27  HN-CHUM-008         CHUM
# 28           28  HN-CHUM-059         CHUM
# 29           29  HN-CHUS-010         CHUS
# ..          ...          ...          ...
# 474         474  HN-CHUM-065         CHUM
# 475         475  HN-CHUM-065         CHUM
# 476         476  HN-CHUS-034         CHUS
# 477         477   HN-HGJ-003          HGJ
# 478         478   HN-HGJ-003          HGJ
# 479         479   HN-HGJ-017          HGJ
# 480         480   HN-HGJ-017          HGJ
# 481         481   HN-HGJ-017          HGJ
# 482         482  HN-CHUM-005         CHUM
# 483         483  HN-CHUM-005         CHUM
# 484         484   HN-HMR-007          HMR
# 485         485   HN-HMR-007          HMR
# 486         486   HN-HGJ-011          HGJ
# 487         487   HN-HGJ-011          HGJ
# 488         488  HN-CHUS-063         CHUS
# 489         489  HN-CHUS-077         CHUS
# 490         490  HN-CHUS-066         CHUS
# 491         491   HN-HMR-036          HMR
# 492         492   HN-HMR-036          HMR
# 493         493   HN-HGJ-042          HGJ
# 494         494   HN-HGJ-042          HGJ
# 495         495  HN-CHUS-068         CHUS
# 496         496   HN-HGJ-092          HGJ
# 497         497   HN-HGJ-092          HGJ
# 498         498  HN-CHUS-031         CHUS
# 499         499  HN-CHUS-052         CHUS
# 500         500  HN-CHUM-034         CHUM
# 501         501  HN-CHUM-034         CHUM
# 502         502  HN-CHUS-061         CHUS
# 503         503  HN-CHUS-003         CHUS
#
#                                                  path1  \
# 0                                  08-27-1885-HN-04353
# 1                   08-27-1885-PET HEAD AND NECK-48050
# 2            08-27-1885-CA ORL FDG TEP POS TRAIT-29027
# 3         08-27-1885-TomoTherapy Patient Disease-41326
# 4      08-27-1885-PANC. avec C.A. SPHRE ORL  -TP-85645
# 5                   08-27-1885-CARCINOME FDG TEP-75326
RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 3        {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 4                 {CT, RTDOSE, PT, RTSTRUCT}
# 5         {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 6                 {RTSTRUCT, RTDOSE, PT, CT}
# 7        {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 8                         {RTSTRUCT, PT, CT}
# 9                        {RTSTRUCT, REG, CT}
# 10                {RTSTRUCT, RTDOSE, PT, CT}
# 11       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 12        {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 13                {CT, RTDOSE, PT, RTSTRUCT}
# 14       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 15                {RTSTRUCT, RTDOSE, PT, CT}
# 16       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 17        {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 18                {CT, RTDOSE, PT, RTSTRUCT}
# 19       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 20       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 21                {CT, RTDOSE, PT, RTSTRUCT}
# 22                       {RTSTRUCT, REG, CT}
# 23                        {RTSTRUCT, PT, CT}
# 24       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 25                {CT, RTDOSE, PT, RTSTRUCT}
# 26                {RTSTRUCT, RTDOSE, PT, CT}
# 27       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 28   {REG, RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 29                        {CT, PT, RTSTRUCT}
# ..                                       ...
# 474               {CT, RTDOSE, PT, RTSTRUCT}
# 475      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 476       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 477                       {RTSTRUCT, PT, CT}
# 478                      {RTSTRUCT, REG, CT}
# 479                               {RTSTRUCT}
# 480                                {CT, REG}
# 481                       {CT, PT, RTSTRUCT}
# 482               {RTSTRUCT, RTDOSE, PT, CT}
# 483      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 484               {CT, RTDOSE, PT, RTSTRUCT}
# 485      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 486                       {RTSTRUCT, PT, CT}
# 487                      {CT, REG, RTSTRUCT}
# 488       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 489       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 490       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 491               {RTSTRUCT, RTDOSE, PT, CT}
# 492      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 493               {RTSTRUCT, RTDOSE, PT, CT}
# 494      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 495       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 496      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 497               {CT, RTDOSE, PT, RTSTRUCT}
# 498       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 499       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 500               {RTSTRUCT, RTDOSE, PT, CT}
# 501      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 502       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 503                       {CT, PT, RTSTRUCT}
#
# [504 rows x 6 columns]

# %%
s = pd.concat([t, df2], axis=1)

# %%
s.drop(columns=['Unnamed: 0'])
# Out:
#          patient instituition  \
# 0     HN-HGJ-040          HGJ
# 1     HN-HGJ-040          HGJ
# 2    HN-CHUS-091         CHUS
# 3    HN-CHUM-026         CHUM
# 4    HN-CHUM-026         CHUM
# 5    HN-CHUS-043         CHUS
# 6     HN-HMR-040          HMR
# 7     HN-HMR-040          HMR
# 8     HN-HGJ-056          HGJ
# 9     HN-HGJ-056          HGJ
# 10    HN-HMR-033          HMR
# 11    HN-HMR-033          HMR
# 12   HN-CHUS-058         CHUS
# 13    HN-HGJ-013          HGJ
# 14    HN-HGJ-013          HGJ
# 15    HN-HMR-011          HMR
# 16    HN-HMR-011          HMR
# 17   HN-CHUS-074         CHUS
# 18    HN-HGJ-084          HGJ
# 19    HN-HGJ-084          HGJ
# 20   HN-CHUM-050         CHUM
# 21   HN-CHUM-050         CHUM
# 22    HN-HGJ-054          HGJ
# 23    HN-HGJ-054          HGJ
# 24    HN-HMR-029          HMR
# 25    HN-HMR-029          HMR
# 26   HN-CHUM-008         CHUM
# 27   HN-CHUM-008         CHUM
# 28   HN-CHUM-059         CHUM
# 29   HN-CHUS-010         CHUS
# ..           ...          ...
# 474  HN-CHUM-065         CHUM
# 475  HN-CHUM-065         CHUM
# 478                  08-27-1885-HN WITH CONTRAST-30071
# 479                                   08-27-1885-65626
# 480                                   08-27-1885-76153
# 481                     08-27-1885-PET HEAD NECK-46758
# 482     08-27-1885-PANC. avec C.A.  PRIMAIRE -TP-17839
# 483       08-27-1885-TomoTherapy Patient Disease-22103
# 484             08-27-1885-ACQUISITIONS SUPPLMEN-01196
# 485             08-27-1885-ACQUISITIONS SUPPLMEN-81475
# 486                     08-27-1885-PET HEAD NECK-60917
# 487                                   08-27-1885-23319
# 488            08-27-1885-TEP cancerologique TEP-33500
# 489                    08-27-1885-CA ORL FDG TEP-33081
# 490      08-27-1885-CA AMYGDALE FDG TEP POSITION-32049
# 491                08-27-1885-PANC. TEP SHRE ORL-87919
# 492                         08-27-1885-LARYNXCOU-64222
# 493                         08-27-1885-PET OTHER-65278
# 494              08-27-1885-SUPRAGLOTTI AND NECK-87861
# 495            08-27-1885-TEP cancerologique TEP-77575
# 496                        08-27-1885-HEAD  NECK-64179
# 497                 08-27-1885-PET HEAD AND NECK-01768
# 498            08-27-1885-TEP cancerologique TEP-55339
# 499             08-27-1885-CA ORL FDG TEP POS TX-94629
# 500         08-27-1885-CT Planification - ORL TC-69506
# 501       08-27-1885-TomoTherapy Patient Disease-83113
# 502            08-27-1885-TEP cancerologique TEP-44835
# 503                     08-27-1885-BILAN INITIAL-49252
#
#                                   Modalities
# 0        {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 1                 {RTSTRUCT, RTDOSE, PT, CT}
# 2         {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 3        {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 4                 {CT, RTDOSE, PT, RTSTRUCT}
# 5         {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 6                 {RTSTRUCT, RTDOSE, PT, CT}
# 7        {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 8                         {RTSTRUCT, PT, CT}
# 9                        {RTSTRUCT, REG, CT}
# 10                {RTSTRUCT, RTDOSE, PT, CT}
# 11       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 12        {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 13                {CT, RTDOSE, PT, RTSTRUCT}
# 14       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 15                {RTSTRUCT, RTDOSE, PT, CT}
# 16       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 17        {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 18                {CT, RTDOSE, PT, RTSTRUCT}
# 19       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 20       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 21                {CT, RTDOSE, PT, RTSTRUCT}
# 22                       {RTSTRUCT, REG, CT}
# 23                        {RTSTRUCT, PT, CT}
# 24       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 25                {CT, RTDOSE, PT, RTSTRUCT}
# 26                {RTSTRUCT, RTDOSE, PT, CT}
# 27       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 28   {REG, RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 29                        {CT, PT, RTSTRUCT}
# ..                                       ...
# 474               {CT, RTDOSE, PT, RTSTRUCT}
# 475      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 476       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 477                       {RTSTRUCT, PT, CT}
# 478                      {RTSTRUCT, REG, CT}
# 479                               {RTSTRUCT}
# 480                                {CT, REG}
# 481                       {CT, PT, RTSTRUCT}
# 482               {RTSTRUCT, RTDOSE, PT, CT}
# 483      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 484               {CT, RTDOSE, PT, RTSTRUCT}
# 485      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 486                       {RTSTRUCT, PT, CT}
# 487                      {CT, REG, RTSTRUCT}
# 488       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 489       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 490       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 491               {RTSTRUCT, RTDOSE, PT, CT}
# 492      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 493               {RTSTRUCT, RTDOSE, PT, CT}
# 494      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 495       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 496      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 497               {CT, RTDOSE, PT, RTSTRUCT}
# 498       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 499       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 500               {RTSTRUCT, RTDOSE, PT, CT}
# 501      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
#
REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 8                         {RTSTRUCT, PT, CT}
# 9                        {RTSTRUCT, REG, CT}
# 10                {RTSTRUCT, RTDOSE, PT, CT}
# 11       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 12        {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 13                {CT, RTDOSE, PT, RTSTRUCT}
# 14       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 15                {RTSTRUCT, RTDOSE, PT, CT}
# 16       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 17        {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 18                {CT, RTDOSE, PT, RTSTRUCT}
# 19       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 20       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 21                {CT, RTDOSE, PT, RTSTRUCT}
# 22                       {RTSTRUCT, REG, CT}
# 23                        {RTSTRUCT, PT, CT}
# 24       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 25                {CT, RTDOSE, PT, RTSTRUCT}
# 26                {RTSTRUCT, RTDOSE, PT, CT}
# 27       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 28   {REG, RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 29                        {CT, PT, RTSTRUCT}
# ..                                       ...
# 474               {CT, RTDOSE, PT, RTSTRUCT}
# 475      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 476       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 477                       {RTSTRUCT, PT, CT}
# 478                      {RTSTRUCT, REG, CT}
# 479                               {RTSTRUCT}
# 480                                {CT, REG}
# 481                       {CT, PT, RTSTRUCT}
# 482               {RTSTRUCT, RTDOSE, PT, CT}
# 483      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 484               {CT, RTDOSE, PT, RTSTRUCT}
# 485      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 486                       {RTSTRUCT, PT, CT}
# 487                      {CT, REG, RTSTRUCT}
# 488       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 489       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 490       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 491               {RTSTRUCT, RTDOSE, PT, CT}
# 492      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 493               {RTSTRUCT, RTDOSE, PT, CT}
# 494      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 495       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 496      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 497               {CT, RTDOSE, PT, RTSTRUCT}
# 498       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 499       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 500               {RTSTRUCT, RTDOSE, PT, CT}
# 501      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 502       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 503                       {CT, PT, RTSTRUCT}
#
# [504 rows x 5 columns]

# %%
result.drop(columns=['Unnamed: 0'])
# Out:
#          patient instituition  \
# 0     HN-HGJ-040          HGJ
# 1     HN-HGJ-040          HGJ
# 2    HN-CHUS-091         CHUS
# 3    HN-CHUM-026         CHUM
# 4    HN-CHUM-026         CHUM
# 5    HN-CHUS-043         CHUS
# 6     HN-HMR-040          HMR
# 7     HN-HMR-040          HMR
# 8     HN-HGJ-056          HGJ
# 9     HN-HGJ-056          HGJ
# 10    HN-HMR-033          HMR
# 11    HN-HMR-033          HMR
# 12   HN-CHUS-058         CHUS
# 13    HN-HGJ-013          HGJ
# 14    HN-HGJ-013          HGJ
# 15    HN-HMR-011          HMR
# 16    HN-HMR-011          HMR
# 17   HN-CHUS-074         CHUS
# 18    HN-HGJ-084          HGJ
# 19    HN-HGJ-084          HGJ
# 20   HN-CHUM-050         CHUM
# 21   HN-CHUM-050         CHUM
# 22    HN-HGJ-054          HGJ
# 23    HN-HGJ-054          HGJ
# 24    HN-HMR-029          HMR
# 25    HN-HMR-029          HMR
# 26   HN-CHUM-008         CHUM
# 27   HN-CHUM-008         CHUM
# 28   HN-CHUM-059         CHUM
# 29   HN-CHUS-010         CHUS
# ..           ...          ...
# 474  HN-CHUM-065         CHUM
# 475  HN-CHUM-065         CHUM
# 476  HN-CHUS-034         CHUS
# 477   HN-HGJ-003          HGJ
# 478   HN-HGJ-003          HGJ
# 479   HN-HGJ-017          HGJ
# 480   HN-HGJ-017          HGJ
# 481   HN-HGJ-017          HGJ
# 485             08-27-1885-ACQUISITIONS SUPPLMEN-81475
# 486                     08-27-1885-PET HEAD NECK-60917
# 487                                   08-27-1885-23319
# 488            08-27-1885-TEP cancerologique TEP-33500
# 489                    08-27-1885-CA ORL FDG TEP-33081
# 490      08-27-1885-CA AMYGDALE FDG TEP POSITION-32049
# 491                08-27-1885-PANC. TEP SHRE ORL-87919
# 492                         08-27-1885-LARYNXCOU-64222
# 493                         08-27-1885-PET OTHER-65278
# 494              08-27-1885-SUPRAGLOTTI AND NECK-87861
# 495            08-27-1885-TEP cancerologique TEP-77575
# 496                        08-27-1885-HEAD  NECK-64179
# 497                 08-27-1885-PET HEAD AND NECK-01768
# 498            08-27-1885-TEP cancerologique TEP-55339
# 499             08-27-1885-CA ORL FDG TEP POS TX-94629
# 500         08-27-1885-CT Planification - ORL TC-69506
# 501       08-27-1885-TomoTherapy Patient Disease-83113
# 502            08-27-1885-TEP cancerologique TEP-44835
# 503                     08-27-1885-BILAN INITIAL-49252
#
#                                   Modalities
# 0        {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 1                 {RTSTRUCT, RTDOSE, PT, CT}
# 2         {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 3        {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 4                 {CT, RTDOSE, PT, RTSTRUCT}
# 5         {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 6                 {RTSTRUCT, RTDOSE, PT, CT}
# 7        {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 8                         {RTSTRUCT, PT, CT}
# 9                        {RTSTRUCT, REG, CT}
# 10                {RTSTRUCT, RTDOSE, PT, CT}
# 11       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 12        {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 13                {CT, RTDOSE, PT, RTSTRUCT}
# 14       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 15                {RTSTRUCT, RTDOSE, PT, CT}
# 16       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 17        {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 18                {CT, RTDOSE, PT, RTSTRUCT}
# 19       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 20       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 21                {CT, RTDOSE, PT, RTSTRUCT}
# 22                       {RTSTRUCT, REG, CT}
# 23                        {RTSTRUCT, PT, CT}
# 24       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 25                {CT, RTDOSE, PT, RTSTRUCT}
# 26                {RTSTRUCT, RTDOSE, PT, CT}
# 27       {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 28   {REG, RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 29                        {CT, PT, RTSTRUCT}
# ..                                       ...
# 474               {CT, RTDOSE, PT, RTSTRUCT}
# 475      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 476       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 477                       {RTSTRUCT, PT, CT}
# 478                      {RTSTRUCT, REG, CT}
# 479                               {RTSTRUCT}
# 480                                {CT, REG}
# 481                       {CT, PT, RTSTRUCT}
# 482               {RTSTRUCT, RTDOSE, PT, CT}
# 483      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 484               {CT, RTDOSE, PT, RTSTRUCT}
# 485      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 486                       {RTSTRUCT, PT, CT}
# 487                      {CT, REG, RTSTRUCT}
# 488       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 489       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 490       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 491               {RTSTRUCT, RTDOSE, PT, CT}
# 492      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 493               {RTSTRUCT, RTDOSE, PT, CT}
# 494      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 495       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 496      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 497               {CT, RTDOSE, PT, RTSTRUCT}
# 498       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 499       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 500               {RTSTRUCT, RTDOSE, PT, CT}
# 501      {REG, RTDOSE, CT, RTPLAN, RTSTRUCT}
# 502       {RTDOSE, PT, CT, RTPLAN, RTSTRUCT}
# 503                       {CT, PT, RTSTRUCT}
#
# [504 rows x 4 columns]

# %%
result.to_csv('final.csv')

# %%
rd = pd.read_csv('final.csv')

# %%
ordem = rd.sort_values(['patient'])

# %%
ordem.to_csv('final2.csv')
